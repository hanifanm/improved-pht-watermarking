# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2
from tabulate import tabulate

# %%
# %run -i ./PHT-RIW-Library.ipynb

# Import images
ori_img = cv2.imread('./assets/lena.png') #BGR
ori_logo = cv2.imread('./assets/paperplane.png', 0)


T_STEP = int(42 / 6) + 1
I_STEP = int(300 / 12) + 1

# %%
constant_image = np.ones((50, 50)).astype('uint8')
imgshow1(constant_image, 'constant_image')

# %%
momen = transformPHT(constant_image, 50, 32)
imgshow1(momen, 'Constant Momen')
# Out:
# Progress: [####################] 100.0%

# %%
new_momen = np.zeros((65, 65))
new_momen[34,34] = 1
new_momen[30,30] = 1
compensation_image = inversePHT(new_momen, 50, 32)
imgshow1(new_momen, 'New Momen')
imgshow1(compensation_image, 'Compensation Image')
# Out:
# Progress: [####################] 100.0%

# %%
new_image = compensation_image + constant_image
imgshow1(new_image, 'New Image')

# %%
new_momen = transformPHT(new_image, 50, 32)
imgshow1(new_momen[:, 30:34], 'New Momen')
# Out:
# Progress: [####################] 100.0%

# %%
new_momen[:, 30:34]
# Out:
# array([[ 0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         -3.73201225e-02-2.04474082e-04j,  0.00000000e+00+0.00000000e+00j],
#        [ 0.00000000e+00+0.00000000e+00j,  8.66665581e-08-4.63053454e-08j,
#         -2.44048466e-02-4.16707216e-03j,  1.32221812e-07-2.09179256e-08j],
#        [ 1.02385867e-01-4.90829736e-02j,  1.71900703e-08-1.53227588e-08j,
#         -4.84061089e-02-5.30506677e-02j,  1.16298971e-07+8.78410010e-08j],
#        [ 6.12421834e-02-5.09077446e-02j,  1.95849094e-07-1.47801952e-08j,
#         -3.80242878e-02-3.60764604e-02j,  3.78525264e-08+2.35100313e-07j],
#        [-2.02843884e-02+4.76624455e-02j, -3.01671550e-08+6.65419095e-08j,
#          6.47529096e-02-1.36770387e-03j, -5.07238020e-08+9.42682852e-08j],
#        [-1.47695294e-02-1.44211673e-02j,  4.73857056e-08-2.15321896e-08j,
#          4.55180472e-02-2.81867001e-02j, -2.05467263e-07-3.19447609e-08j],
#        [ 2.05886212e-02+6.04943443e-02j, -1.84293663e-08+8.98511862e-08j,
#          1.89077037e-02+9.96852272e-03j, -1.58623168e-08-8.50454374e-08j],
#        [ 6.56145023e-02-7.33956986e-04j, -1.61106633e-08+2.83183910e-08j,
#         -1.89137523e-02-1.60147054e-02j, -2.01613166e-08+1.09589540e-08j],
#        [ 7.81577598e-03-4.07149722e-02j, -1.82077340e-08+7.43197516e-09j,
#          6.92874488e-03+5.92108636e-02j, -8.30176238e-09-6.86790420e-08j],
#        [-5.92986627e-02+9.72145167e-02j, -3.01448830e-09-9.21328516e-09j,
#          1.19784275e-02-2.67728142e-02j, -4.61320986e-08-6.24770335e-09j],
#        [-1.39423452e-03-2.00087631e-02j, -1.38671810e-08+5.25592779e-08j,
#          8.86248241e-03-1.17217304e-02j, -6.23475372e-08-2.78063029e-08j],
#        [ 8.30735229e-03-1.08751575e-02j, -4.75335180e-08-2.82459468e-09j,
#         -3.46414380e-02+5.34035950e-02j,  2.05579718e-08-5.51119639e-09j],
#        [-2.63684418e-03-1.89232939e-02j,  1.05486160e-09-3.56942854e-08j,
#          1.94112320e-03-3.13619903e-02j, -1.93006623e-09+2.92428027e-08j],
#        [-1.16513189e-02-3.46029876e-03j, -1.59548452e-08-3.63822104e-08j,
#         -3.03299734e-02-3.21354179e-02j,  2.83479778e-08-4.21518712e-08j],
#        [ 1.01304750e-01+1.10372382e-02j, -1.42566258e-08+3.79490386e-08j,
#          4.65234499e-02+3.00466357e-03j, -1.49417653e-08-6.69948705e-09j],
#        [-5.48923989e-02+7.49319247e-02j,  7.12827346e-08+2.22179622e-08j,
#         -2.23828734e-02-1.49102723e-02j,  8.34559007e-09+1.45769060e-07j],
#        [-2.11423723e-02+1.98077216e-02j, -1.14936720e-07+4.80374992e-09j,
#          4.79327295e-02-4.61809939e-04j, -3.60189189e-08-3.82542758e-08j],
#        [-5.67507528e-02-2.91260691e-02j,  1.24375051e-08+6.01131327e-08j,
#         -1.63345045e-02+4.31786165e-02j, -5.32649765e-08-1.90647377e-08j],
#        [ 3.56245342e-02-1.64083221e-02j, -1.30943883e-08+6.49336622e-09j,
#         -3.62506193e-02-1.36603480e-02j,  3.11451171e-08-3.40832353e-08j],
#        [-1.97249520e-02+3.70736785e-02j, -2.78727766e-08-3.44318419e-09j,
#         -3.74801415e-03-2.92850504e-02j,  4.50334292e-09-3.49901210e-08j],
#        [-4.13236836e-02-1.55939824e-02j, -1.64285718e-08-1.85045728e-08j,
#          1.06874337e-02-1.80460467e-02j,  1.83977774e-08-6.66331417e-11j],
#        [-8.92762644e-03-3.15694705e-02j, -1.39264390e-09+2.19181092e-08j,
#          1.18949072e-02-9.47421537e-03j,  2.97794399e-09-5.05200433e-09j],
#        [ 6.58479146e-03-2.02246030e-02j, -5.44297662e-11+1.60869330e-08j,
#          1.05271929e-02-5.48324897e-03j,  1.15403326e-08-2.93077740e-08j],
#        [ 8.55221824e-03-1.11444057e-02j,  1.90640516e-08+1.14900612e-08j,
#          9.27583534e-03-3.58756030e-03j,  4.01269976e-08+1.81629601e-08j],
#        [ 7.62325312e-03-6.69168842e-03j, -9.50068214e-09+2.03764971e-09j,
#          8.38368768e-03-2.54751761e-03j,  1.41898890e-09-6.70490315e-09j],
#        [ 6.65703858e-03-4.44493048e-03j,  2.98471321e-10-2.17535475e-08j,
#          7.75577490e-03-1.89328077e-03j, -1.66127422e-08-7.36152024e-09j],
#        [ 5.97829200e-03-3.13563654e-03j,  1.51205455e-08+2.67387917e-08j,
#          7.30523842e-03-1.43705309e-03j,  2.82760498e-08+1.75161586e-08j],
#        [ 5.52536177e-03-2.26433825e-03j, -1.59773828e-08-8.82457016e-09j,
#          6.97736615e-03-1.09248078e-03j, -7.76038601e-09-1.14740933e-08j],
#        [ 5.22747678e-03-1.62404176e-03j,  7.75647387e-09+2.72861507e-09j,
#          6.73876075e-03-8.15988560e-04j,  1.97596815e-09-3.77327635e-09j],
#        [ 5.04035111e-03-1.11567142e-03j, -5.27218991e-09-7.69200560e-09j,
#          6.56909071e-03-5.82206860e-04j,  1.62093040e-08-3.04519071e-09j],
#        [ 1.00493767e+00-6.84949131e-04j,  1.19503608e-08-5.49066228e-09j,
#          6.45539402e-03-3.75118466e-04j, -7.48111648e-09+4.38098597e-09j],
#        [ 4.90506464e-03-2.98758196e-04j,  4.81087743e-09+8.89384473e-09j,
#          6.38992682e-03-1.83927613e-04j, -4.73452850e-09+5.64430469e-09j],
#        [ 4.93639215e-03+6.68547463e-05j, -5.77635306e-09-2.93893192e-09j,
#          1.00636854e+00+0.00000000e+00j, -5.77635306e-09+2.93893192e-09j],
#        [ 5.03113273e-03+4.31915011e-04j, -4.73452850e-09-5.64430469e-09j,
#          6.38992682e-03+1.83927613e-04j,  4.81087743e-09-8.89384473e-09j],
#        [ 5.19475099e-03+8.15987273e-04j, -7.48111648e-09-4.38098597e-09j,
#          6.45539402e-03+3.75118466e-04j,  1.19503608e-08+5.49066228e-09j],
#        [ 5.43940319e-03+1.24281736e-03j,  1.62093040e-08+3.04519071e-09j,
#          6.56909071e-03+5.82206860e-04j, -5.27218991e-09+7.69200560e-09j],
#        [ 5.78623286e-03+1.74521116e-03j,  1.97596815e-09+3.77327635e-09j,
#          6.73876075e-03+8.15988560e-04j,  7.75647387e-09-2.72861507e-09j],
#        [ 6.27089363e-03+2.37602165e-03j, -7.76038601e-09+1.14740933e-08j,
#          6.97736615e-03+1.09248078e-03j, -1.59773828e-08+8.82457016e-09j],
#        [ 6.95283982e-03+3.23246788e-03j,  2.82760498e-08-1.75161586e-08j,
#          7.30523842e-03+1.43705309e-03j,  1.51205455e-08-2.67387917e-08j],
#        [ 7.92639264e-03+4.51908027e-03j, -1.66127422e-08+7.36152024e-09j,
#          7.75577490e-03+1.89328077e-03j,  2.98471321e-10+2.17535475e-08j],
#        [ 9.29933186e-03+6.73216372e-03j,  1.41898890e-09+6.70490315e-09j,
#          8.38368768e-03+2.54751761e-03j, -9.50068214e-09-2.03764971e-09j],
#        [ 1.08509877e-02+1.11564413e-02j,  4.01269976e-08-1.81629601e-08j,
#          9.27583534e-03+3.58756030e-03j,  1.90640516e-08-1.14900612e-08j],
#        [ 9.92711860e-03+2.03655800e-02j,  1.15403326e-08+2.93077740e-08j,
#          1.05271929e-02+5.48324897e-03j, -5.44297662e-11-1.60869330e-08j],
#        [-4.06839930e-03+3.26374867e-02j,  2.97794399e-09+5.05200433e-09j,
#          1.18949072e-02+9.47421537e-03j, -1.39264390e-09-2.19181092e-08j],
#        [-3.59329460e-02+1.89148150e-02j,  1.83977774e-08+6.66331417e-11j,
#          1.06874337e-02+1.80460467e-02j, -1.64285718e-08+1.85045728e-08j],
#        [-1.55375645e-02-3.39274698e-02j,  4.50334292e-09+3.49901210e-08j,
#         -3.74801415e-03+2.92850504e-02j, -2.78727766e-08+3.44318419e-09j],
#        [ 4.61338612e-02+1.81386583e-02j,  3.11451171e-08+3.40832353e-08j,
#         -3.62506193e-02+1.36603480e-02j, -1.30943883e-08-6.49336622e-09j],
#        [-4.05866232e-02+4.28922136e-02j, -5.32649765e-08+1.90647377e-08j,
#         -1.63345045e-02-4.31786165e-02j,  1.24375051e-08-6.01131327e-08j],
#        [-5.32759517e-03+7.10610420e-03j, -3.60189189e-08+3.82542758e-08j,
#          4.79327295e-02+4.61809939e-04j, -1.14936720e-07-4.80374992e-09j],
#        [-6.19496826e-02-1.44126351e-02j,  8.34559007e-09-1.45769060e-07j,
#         -2.23828734e-02+1.49102723e-02j,  7.12827346e-08-2.22179622e-08j],
#        [ 2.68776840e-02+2.97242516e-02j, -1.49417653e-08+6.69948705e-09j,
#          4.65234499e-02-3.00466357e-03j, -1.42566258e-08-3.79490386e-08j],
#        [-8.76438201e-02-5.35624509e-02j,  2.83479778e-08+4.21518712e-08j,
#         -3.03299734e-02+3.21354179e-02j, -1.59548452e-08+3.63822104e-08j],
#        [ 2.39705612e-02-2.17460382e-02j, -1.93006623e-09-2.92428027e-08j,
#          1.94112320e-03+3.13619903e-02j,  1.05486160e-09+3.56942854e-08j],
#        [-2.65786497e-02-4.97967587e-03j,  2.05579718e-08+5.51119639e-09j,
#         -3.46414380e-02-5.34035950e-02j, -4.75335180e-08+2.82459468e-09j],
#        [ 6.03004559e-02-7.07101288e-02j, -6.23475372e-08+2.78063029e-08j,
#          8.86248241e-03+1.17217304e-02j, -1.38671810e-08-5.25592779e-08j],
#        [-8.18201263e-03+4.56476604e-03j, -4.61320986e-08+6.24770335e-09j,
#          1.19784275e-02+2.67728142e-02j, -3.01448830e-09+9.21328516e-09j],
#        [-3.02521348e-02+1.19595977e-02j, -8.30176238e-09+6.86790420e-08j,
#          6.92874488e-03-5.92108636e-02j, -1.82077340e-08-7.43197516e-09j],
#        [ 8.41551897e-02+6.92708903e-03j, -2.01613166e-08-1.09589540e-08j,
#         -1.89137523e-02+1.60147054e-02j, -1.61106633e-08-2.83183910e-08j],
#        [ 6.14177098e-02-9.98545544e-03j, -1.58623168e-08+8.50454374e-08j,
#          1.89077037e-02-9.96852272e-03j, -1.84293663e-08-8.98511862e-08j],
#        [-6.26816379e-02-7.73392194e-03j, -2.05467263e-07+3.19447609e-08j,
#          4.55180472e-02+2.81867001e-02j,  4.73857056e-08+2.15321896e-08j],
#        [-4.94524419e-02+8.20439902e-02j, -5.07238020e-08-9.42682852e-08j,
#          6.47529096e-02+1.36770387e-03j, -3.01671550e-08-6.65419095e-08j],
#        [ 2.92312315e-02-2.18723430e-02j,  3.78525264e-08-2.35100313e-07j,
#         -3.80242878e-02+3.60764604e-02j,  1.95849094e-07+1.47801952e-08j],
#        [-2.36600809e-02-1.07854699e-03j,  1.16298971e-07-8.78410010e-08j,
#         -4.84061089e-02+5.30506677e-02j,  1.71900703e-08+1.53227588e-08j],
#        [ 0.00000000e+00+0.00000000e+00j,  1.32221812e-07+2.09179256e-08j,
#         -2.44048466e-02+4.16707216e-03j,  8.66665581e-08+4.63053454e-08j],
#        [ 0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         -3.73201225e-02+2.04474082e-04j,  0.00000000e+00+0.00000000e+00j]])

# %%
def fullAttack(image):
    multipleAttacked = np.copy(image)
    multipleAttacked = attackRotation(multipleAttacked, 10)
    multipleAttacked = attackResize(multipleAttacked, 300)
    multipleAttacked = attackNoiseSaltPepper(multipleAttacked, 0.03)
    multipleAttacked = attackFilterAverage(multipleAttacked, 3)
    multipleAttacked = attackCrop(multipleAttacked, 0.03, 0.03, 0.03, 0.03)
    multipleAttacked = attackJPG(multipleAttacked, 90)
    return multipleAttacked

# %%
def process(n, g, p, d):
    p2 = 2 * p + 1
    
    # Preprocess Image
    imgBgr = cv2.resize(ori_img, (n, n)) # Original Image
    imgY = getYFromBGR(imgBgr) #

    # Preprocess Logo
    logo = cv2.resize(ori_logo, (g, g))
    logo = (logo >= 128) * 1
    
    imgWatermarked = watermarkEmbedToImage(imgBgr, logo, n, g, p, d)
    
    mse = np.mean((imgWatermarked - imgBgr) ** 2)
    psnr = 10 * np.log10(255 * 255 / mse)
    
    imgAttacked = fullAttack(imgWatermarked)
    
    (logo2, ber, trf) = watermarkExtractFromImage(imgAttacked, imgWatermarked, logo, n, g, p, d, False)
    
    return (imgBgr, logo, imgWatermarked, logo2, psnr, ber)

# %%
(imgBgr, logo, imgWatermarked, logo2, psnr, ber) = process(320, 24, 36, 0.4)

print('PSNR = {}'.format(psnr))
print('BER = {}'.format(ber))

imgshow([[imgBgr, imgWatermarked]], [['Original Image', 'Watermarked Image']])
imgshow([[logo, logo2]], [['Original Logo', 'Extracted Logo']])
# Out:
# Progress: [####################] 100.0%
# PSNR = 31.90637807435053
# BER = 0.24131944444444445

# %%
np.arctan2(0, -1)
# Out:
# 3.141592653589793

# %%
# Steps

N = 320
G = 24
P = 36
D = 0.4

P2 = 2 * P + 1

T_STEP = int(P / 6) + 1
I_STEP = int(N / 12) + 1

# %run -i ./PHT-RIW-Library.ipynb

# %%
imgWatermarked = watermarkEmbedToImage(IMG_BGR, LOGO, n, g, p, d)
imgshow1(imgWatermarked, 'Watermarked Image')
# Out:
# Generating Compensation Image
#
# Progress: [####################] 100.0%

# %%
# Calculate PSNR
MSE = np.mean((imgWatermarked - IMG_BGR) ** 2)
PSNR = 10 * np.log10(255 * 255 / MSE)

print(tabulate([[n, g, p, d, PSNR]], headers=['N', 'G', 'P', 'D', 'PSNR'], tablefmt='orgtbl'))
# Out:
# |   N |   G |   P |   D |    PSNR |
# |-----+-----+-----+-----+---------|
# | 320 |  24 |  36 | 0.4 | 31.5958 |

# %%
# Multiple Attacks

# %%
imgshow1(multipleAttacked, 'MultipleAttack')

# %%
(miLogo, miBer, miTrf) = watermarkExtractFromImage(multipleAttacked, IMG_WATERMARKED, LOGO, n, g, p, d, False, 'N={} G={} P={} D={}\n{}'.format(n, g, p, d, 'MultipleAttack'))

clear_output(wait = True)
print('BER = {:.2%}'.format(miBer))
print(miTrf)
imgshow([[multipleAttacked, miLogo]], [['MultipleAttack', 'Extracted Watermark']])
# Out:
# BER = 17.53%
# (0, 0, 1)
